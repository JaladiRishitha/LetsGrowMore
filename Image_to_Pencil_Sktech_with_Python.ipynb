# %% [markdown]
# <a href="https://colab.research.google.com/github/JaladiRishitha/LetsGrowMore/blob/main/Image_to_Pencil_Sktech_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
image=cv2.imread("cap.jpg")
grey_img=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
invert=cv2.bitwise_not(grey_img)
blur=cv2.GaussianBlur(invert,(21,21),0)
invertedblur=cv2.bitwise_not(blur)
sketch=cv2.divide(grey_img,invertedblur,scale=256.0)
cv2.imwrite("sk.png",sketch)
plt.imshow(cv2.cvtColor(sketch, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
